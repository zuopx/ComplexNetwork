# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# # Tick

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.tick_params.html#matplotlib.axes.Axes.tick_params

# %%
ax.tick_params(direction='in', bottom=True, top=True, left=True, right=True)

# %% [markdown]
# # 箭头

# %% [markdown]
# https://matplotlib.org/gallery/text_labels_and_annotations/arrow_simple_demo.html#sphx-glr-gallery-text-labels-and-annotations-arrow-simple-demo-py

# %%
ax.arrow(0.5, 0.5, -0.1, 0, head_width = 0.02, head_length=0.05)

# %% [markdown]
# # 横线或竖线

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.axhline.html#matplotlib.axes.Axes.axhline

# %% [markdown]
# # 文字

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.text.html#matplotlib.axes.Axes.text

# %% [markdown]
# # label

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.legend.html#matplotlib.axes.Axes.legend

# %% [markdown]
# # 对数坐标

# %% [markdown]
# Axes.loglog
# Axes.semilogx
# Axes.semilogy
# ax.set_xscale('log')
# ax.set_yscale('log')

# %%
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 拼图

# %%
fig, ax = plt.subplots()
ax.plot([1, 3, 2])
ax.set_ylabel(r'$\frac{S(\mathcal{V}_0^{GIN})}{S(\mathcal{V}_\beta^{GIN})}$', fontsize=20)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
